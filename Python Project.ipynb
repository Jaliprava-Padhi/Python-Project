# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv("TB_Burden_Country.csv")

# %%
marvel.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...

# %%
marvel.shape
# Out:
# (5120, 47)

# %%
marvel['ISO 3-character country/territory code'].value_counts()
# Out:
# ISO 3-character country/territory code
# AFG    24
# NLD    24
# NZL    24
# NIC    24
# NER    24
#        ..
# MNE     9
# CUW     4
# BES     4
# SXM     4
# SSD     3
# Name: count, Length: 219, dtype: int64

# %%
marvel[marvel['ISO 3-character country/territory code']=="AFG"]
# Out:
#    Country or territory name ISO 2-character country/territory code  \
# 0                Afghanistan                                     AF
# 1                Afghanistan                                     AF
# 2                Afghanistan                                     AF
# 3                Afghanistan                                     AF
# 4                Afghanistan                                     AF
# 5                Afghanistan                                     AF
# 6                Afghanistan                                     AF
# 7                Afghanistan                                     AF
# 8                Afghanistan                                     AF
# 9                Afghanistan                                     AF
# 10               Afghanistan                                     AF
# 11               Afghanistan                                     AF
# 12               Afghanistan                                     AF
# ...

# %%
marvel.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...

# %%
marvel.sort_values(by=['Year'],ascending=False)
# Out:
#      Country or territory name ISO 2-character country/territory code  \
# 5119                  Zimbabwe                                     ZW
# 4999                  Viet Nam                                     VN
# 891                     Canada                                     CA
# 3804                    Rwanda                                     RW
# 2359                    Jordan                                     JO
# ...                        ...                                    ...
# 4021                Seychelles                                     SC
# 552                     Bhutan                                     BT
# 1976             Guinea-Bissau                                     GW
# 1952                    Guinea                                     GN
# 0                  Afghanistan                                     AF
#
#      ISO 3-character country/territory code  \
# 5119                                    ZWE
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(list(marvel['Estimated incidence of TB cases who are HIV-positive per 100 000 population'])[0:5],list(marvel['Year'])[0:5],color="g")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(list(marvel['Estimated incidence of TB cases who are HIV-positive'])[0:5],list(marvel['Estimated total population number'])[0:5],color=["red","green","blue","orange","pink"])
plt.show()

# %%
#making a histogram for Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound
plt.figure(figsize=(5,7))
plt.hist(marvel['Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound'])
plt.title("Distributation of Estimated incidence of TB cases who are HIV-positive per 100 000 population, high bound")
plt.show()

# %%
marvel.head()
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...
